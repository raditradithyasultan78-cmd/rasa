# %% [markdown]
# <a href="https://colab.research.google.com/github/raditradithyasultan78-cmd/rasa/blob/main/python_Rasa_Nusantara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Selamat datang di game Rasa Nusantara")
print("1. Rendang")
print("2. Pisang Ijo")
print("3. Kerak Telor")
print("4. Pempek")
print("5. Papeda")
print("6. Bika Ambon")
print("7. Ayam Taliwang")
print("8. Gudeg")
print("9. Soto Banjar")

pilihan = int(input("Masukkan angka: "))

if pilihan == 1:
    print("Rendang adalah makanan khas Sumatera Barat yang terbuat dari daging sapi dan santan.")
elif pilihan == 2:
    print("Pisang Ijo adalah makanan khas Makassar berupa pisang yang dibalut adonan hijau.")
elif pilihan == 3:
    print("Kerak Telor adalah makanan khas Jakarta yang terbuat dari beras ketan dan telur.")
elif pilihan == 4:
    print("Pempek adalah makanan khas Palembang yang terbuat dari ikan dan tepung sagu.")
elif pilihan == 5:
    print("Papeda adalah makanan khas Papua yang terbuat dari sagu.")
elif pilihan == 6:
    print("Bika Ambon adalah kue khas Medan yang bertekstur berongga.")
elif pilihan == 7:
    print("Ayam Taliwang adalah makanan khas Lombok yang terkenal dengan cita rasa pedasnya.")
elif pilihan == 8:
    print("Gudeg adalah makanan khas Yogyakarta yang terbuat dari nangka muda.")
elif pilihan == 9:
    print("Soto Banjar adalah soto khas Kalimantan Selatan dengan kuah berempah.")
else:
    print("Pilihan tidak tersedia.")
# Out:
# Selamat datang di game Rasa Nusantara
# 1. Rendang
# 2. Pisang Ijo
# 3. Kerak Telor
# 4. Pempek
# 5. Papeda
# 6. Bika Ambon
# 7. Ayam Taliwang
# 8. Gudeg
# 9. Soto Banjar
# Masukkan angka: 3
# Kerak Telor adalah makanan khas Jakarta yang terbuat dari beras ketan dan telur.
